# %%
import tensorflow as tf
import numpy as np

# %%
tf.set_random_seed(777)  # for reproducibility

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# Variables2
W1 = tf.Variable(tf.random_normal([2,2]), name='weight1')
b1 = tf.Variable(tf.random_normal([2]), name='bias1')

# %%
# Layer1
layer = tf.sigmoid(tf.matmul(X, W1)+b1)

# %%
# Variables2
W2 = tf.Variable(tf.random_normal([2,1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')

# %%
# Hypothesis
hypothesis = tf.sigmoid(tf.matmul(layer, W2)+b2)

# %%
# Cost
cost = -tf.reduce_mean(Y*tf.log(hypothesis) + (1-Y)*tf.log(1-hypothesis))

# %%
# Minimize cost
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train = optimizer.minimize(cost)

# %%
# Accuracy
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
# Fit the train
with tf.Session() as session:
    session.run(tf.global_variables_initializer())
    
    for step in range(1, 10001):
        cost_val, hypothesis_val, _ = session.run([cost, hypothesis, train], 
                                                  feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, hypothesis_val, cost_val)
    
    c_val, p_val, a_val = session.run([cost, predicted, accuracy],
                                      feed_dict={X: x_data, Y: y_data})
    print("C_val:", c_val, "\n, Expected:", p_val, ",\n Accuracy:", a_val)
# Out:
# 100 [[0.46045813]
#  [0.47387162]
#  [0.5423348 ]
#  [0.54811937]] 0.6925157
# 200 [[0.45436585]
#  [0.4806055 ]
#  [0.53593683]
#  [0.54644084]] 0.6882209
# 300 [[0.4499482 ]
#  [0.48758322]
#  [0.53351307]
#  [0.5478641 ]] 0.68452036
# 400 [[0.44493353]
#  [0.4934655 ]
#  [0.5323852 ]
#  [0.55004615]] 0.680992
# 500 [[0.43906438]
#  [0.49872473]
#  [0.5322352 ]
#  [0.5529045 ]] 0.67737573
# 600 [[0.4321143]
#  [0.5036954]
#  [0.5329081]
#  [0.5564332]] 0.67348295
# 700 [[0.4238528 ]
#  [0.5086224 ]
#  [0.53432924]
#  [0.56065255]] 0.6691623
# 800 [[0.41404974]
#  [0.5136949 ]
#  [0.5364722 ]
#  [0.5655881 ]] 0.6642872
# 900 [[0.4024978 ]
#  [0.51906186]
#  [0.53933465]
#  [0.57124954]] 0.65875715
# 1000 [[0.38905317]
#  [0.52483237]
#  [0.542918  ]
#  [0.57760704]] 0.65250945
# 1100 [[0.37368673]
#  [0.53106767]
#  [0.5472079 ]
#  [0.584569  ]] 0.6455339
# 1200 [[0.35653043]
#  [0.5377694 ]
#  [0.5521548 ]
#  [0.5919696 ]] 0.63788664
# 1300 [[0.33789477]
#  [0.54487425]
#  [0.55766445]
#  [0.5995777 ]] 0.6296911
# 1400 [[0.3182409 ]
#  [0.5522588 ]
#  [0.56359744]
#  [0.6071279 ]] 0.6211259
# 1500 [[0.2981111 ]
#  [0.55975896]
#  [0.56978333]
#  [0.61436564]] 0.6123985
# 1600 [[0.2780459 ]
#  [0.56719995]
#  [0.57604426]
#  [0.62108946]] 0.6037158
# 1700 [[0.25851372]
#  [0.5744208 ]
#  [0.5822153 ]
#  [0.62717   ]] 0.59525985
# 1800 [[0.23987362]
#  [0.5812948 ]
#  [0.58816385]
#  [0.63255227]] 0.5871729
# 1900 [[0.22236516]
#  [0.587736  ]
#  [0.5937943 ]
#  [0.6372386 ]] 0.579552
# 2000 [[0.20612107]
#  [0.5936975 ]
#  [0.5990489 ]
#  [0.64127135]] 0.57245266
# 2100 [[0.19118747]
#  [0.5991644 ]
#  [0.60390097]
#  [0.64471364]] 0.5658959
# 2200 [[0.17754796]
#  [0.60414493]
#  [0.6083471 ]
#  [0.64763683]] 0.5598772
# 2300 [[0.16514498]
#  [0.6086633 ]
#  [0.6124008 ]
#  [0.6501127 ]] 0.55437493
# 2400 [[0.1538961 ]
#  [0.612752  ]
#  [0.6160848 ]
#  [0.65220726]] 0.5493568
# 2500 [[0.14370692]
#  [0.61644745]
#  [0.61942756]
#  [0.6539802 ]] 0.54478586
# 2600 [[0.13448001]
#  [0.6197876 ]
#  [0.6224592 ]
#  [0.6554828 ]] 0.54062295
# 2700 [[0.12612006]
#  [0.6228085 ]
#  [0.6252098 ]
#  [0.656759  ]] 0.53682977
# 2800 [[0.11853711]
#  [0.6255446 ]
#  [0.6277078 ]
#  [0.65784574]] 0.5333698
# 2900 [[0.11164863]
#  [0.62802655]
#  [0.6299801 ]
#  [0.6587738 ]] 0.53020936
# 3000 [[0.10537967]
#  [0.63028246]
#  [0.63205045]
#  [0.6595688 ]] 0.5273178
# 3100 [[0.09966317]
#  [0.63233745]
#  [0.63394094]
#  [0.66025203]] 0.52466726
# 3200 [[0.09443932]
#  [0.6342135 ]
#  [0.6356705 ]
#  [0.66084087]] 0.5222329
# 3300 [[0.08965518]
#  [0.6359301 ]
#  [0.63725615]
#  [0.6613498 ]] 0.51999235
# 3400 [[0.0852644 ]
#  [0.6375053 ]
#  [0.63871384]
#  [0.66179156]] 0.5179261
# 3500 [[0.08122554]
#  [0.63895357]
#  [0.64005655]
#  [0.6621758 ]] 0.5160166
# 3600 [[0.07750235]
#  [0.640288  ]
#  [0.6412955 ]
#  [0.6625106 ]] 0.51424843
# 3700 [[0.07406298]
#  [0.6415207 ]
#  [0.64244163]
#  [0.6628031 ]] 0.5126076
# 3800 [[0.0708792 ]
#  [0.64266163]
#  [0.64350426]
#  [0.6630592 ]] 0.51108205
# 3900 [[0.06792603]
#  [0.6437202 ]
#  [0.644491  ]
#  [0.6632837 ]] 0.5096608
# 4000 [[0.06518157]
#  [0.6447043 ]
#  [0.6454096 ]
#  [0.6634809 ]] 0.5083343
# 4100 [[0.06262621]
#  [0.64562106]
#  [0.64626586]
#  [0.663654  ]] 0.5070937
# 4200 [[0.06024262]
#  [0.6464769 ]
#  [0.6470658 ]
#  [0.6638063 ]] 0.5059316
# 4300 [[0.05801544]
#  [0.64727736]
#  [0.64781475]
#  [0.66393995]] 0.5048407
# 4400 [[0.05593091]
#  [0.64802736]
#  [0.6485167 ]
#  [0.6640574 ]] 0.5038152
# 4500 [[0.05397682]
#  [0.64873177]
#  [0.6491763 ]
#  [0.6641604 ]] 0.50284916
# 4600 [[0.05214205]
#  [0.64939374]
#  [0.64979625]
#  [0.66425025]] 0.5019381
# 4700 [[0.0504169 ]
#  [0.65001756]
#  [0.6503803 ]
#  [0.66432834]] 0.501077
# 4800 [[0.0487926 ]
#  [0.65060645]
#  [0.6509319 ]
#  [0.6643963 ]] 0.500262
# 4900 [[0.04726104]
#  [0.6511629 ]
#  [0.6514528 ]
#  [0.66445464]] 0.49948955
# 5000 [[0.0458151 ]
#  [0.65168995]
#  [0.6519458 ]
#  [0.6645043 ]] 0.49875605
# 5100 [[0.04444828]
#  [0.65218985]
#  [0.652413  ]
#  [0.66454595]] 0.49805844
# 5200 [[0.04315481]
#  [0.6526646 ]
#  [0.6528567 ]
#  [0.6645803 ]] 0.49739397
# 5300 [[0.04192932]
#  [0.65311635]
#  [0.65327793]
#  [0.6646078 ]] 0.49676028
# 5400 [[0.04076695]
#  [0.6535469 ]
#  [0.65367883]
#  [0.664629  ]] 0.4961548
# 5500 [[0.03966333]
#  [0.6539581 ]
#  [0.65406096]
#  [0.66464394]] 0.49557513
# 5600 [[0.03861449]
#  [0.654351  ]
#  [0.6544253 ]
#  [0.66465354]] 0.49502
# 5700 [[0.03761676]
#  [0.65472704]
#  [0.6547735 ]
#  [0.6646574 ]] 0.494487
# 5800 [[0.03666677]
#  [0.6550881 ]
#  [0.65510666]
#  [0.66465634]] 0.4939745
# 5900 [[0.03576148]
#  [0.65543497]
#  [0.65542567]
#  [0.66464996]] 0.4934809
# 6000 [[0.03489813]
#  [0.65576893]
#  [0.65573144]
#  [0.6646386 ]] 0.4930047
# 6100 [[0.03407414]
#  [0.6560908 ]
#  [0.656025  ]
#  [0.66462237]] 0.49254468
# 6200 [[0.0332872 ]
#  [0.65640193]
#  [0.6563073 ]
#  [0.66460115]] 0.49209923
# 6300 [[0.03253509]
#  [0.65670323]
#  [0.65657896]
#  [0.664575  ]] 0.49166706
# 6400 [[0.03181588]
#  [0.6569953 ]
#  [0.65684056]
#  [0.66454357]] 0.49124715
# 6500 [[0.03112772]
#  [0.6572794 ]
#  [0.65709317]
#  [0.66450715]] 0.49083817
# 6600 [[0.03046897]
#  [0.65755653]
#  [0.6573377 ]
#  [0.66446555]] 0.49043882
# 6700 [[0.02983811]
#  [0.657827  ]
#  [0.6575739 ]
#  [0.6644182 ]] 0.49004832
# 6800 [[0.0292337]
#  [0.6580917]
#  [0.6578027]
#  [0.6643649]] 0.48966533
# 6900 [[0.02865449]
#  [0.6583522 ]
#  [0.6580251 ]
#  [0.6643056 ]] 0.4892887
# 7000 [[0.02809927]
#  [0.6586088 ]
#  [0.6582409 ]
#  [0.6642395 ]] 0.48891717
# 7100 [[0.02756703]
#  [0.65886265]
#  [0.6584516 ]
#  [0.6641666 ]] 0.48854965
# 7200 [[0.0270568 ]
#  [0.65911436]
#  [0.65865695]
#  [0.6640856 ]] 0.4881848
# 7300 [[0.0265677 ]
#  [0.6593654 ]
#  [0.6588575 ]
#  [0.66399676]] 0.4878217
# 7400 [[0.02609899]
#  [0.6596168 ]
#  [0.659054  ]
#  [0.66389865]] 0.48745853
# 7500 [[0.02564999]
#  [0.6598698 ]
#  [0.6592468 ]
#  [0.66379035]] 0.48709375
# 7600 [[0.02522017]
#  [0.6601255 ]
#  [0.6594369 ]
#  [0.6636714 ]] 0.48672614
# 7700 [[0.02480906]
#  [0.66038585]
#  [0.659624  ]
#  [0.6635397 ]] 0.4863534
# 7800 [[0.0244163 ]
#  [0.66065216]
#  [0.6598089 ]
#  [0.6633943 ]] 0.4859738
# 7900 [[0.02404169]
#  [0.66092694]
#  [0.6599924 ]
#  [0.663233  ]] 0.48558456
# 8000 [[0.02368519]
#  [0.66121274]
#  [0.66017544]
#  [0.6630544 ]] 0.48518336
# 8100 [[0.02334685]
#  [0.6615121 ]
#  [0.6603579 ]
#  [0.6628552 ]] 0.48476672
# 8200 [[0.02302686]
#  [0.66182876]
#  [0.6605407 ]
#  [0.66263264]] 0.484331
# 8300 [[0.02272575]
#  [0.66216666]
#  [0.66072446]
#  [0.662383  ]] 0.48387188
# 8400 [[0.02244421]
#  [0.6625315 ]
#  [0.6609096 ]
#  [0.66210127]] 0.48338357
# 8500 [[0.0221833 ]
#  [0.6629301 ]
#  [0.6610979 ]
#  [0.66178256]] 0.4828596
# 8600 [[0.0219447 ]
#  [0.66337174]
#  [0.6612897 ]
#  [0.6614198 ]] 0.48229164
# 8700 [[0.02173044]
#  [0.6638672 ]
#  [0.6614865 ]
#  [0.66100425]] 0.48166916
# 8800 [[0.0215433 ]
#  [0.6644316 ]
#  [0.66168875]
#  [0.6605249 ]] 0.4809792
# 8900 [[0.02138707]
#  [0.66508394]
#  [0.66189677]
#  [0.65996706]] 0.48020488
# 9000 [[0.02126695]
#  [0.6658513 ]
#  [0.66211194]
#  [0.6593126 ]] 0.47932398
# 9100 [[0.02119003]
#  [0.6667712 ]
#  [0.66233385]
#  [0.6585377 ]] 0.47830743
# 9200 [[0.02116616]
#  [0.6678943 ]
#  [0.6625621 ]
#  [0.65760976]] 0.477116
# 9300 [[0.02120906]
#  [0.66929436]
#  [0.66279304]
#  [0.6564854 ]] 0.47569665
# 9400 [[0.02133837]
#  [0.6710771 ]
#  [0.6630204 ]
#  [0.65510505]] 0.47397637
# 9500 [[0.02158217]
#  [0.6733949 ]
#  [0.6632298 ]
#  [0.65338624]] 0.47185493
# 9600 [[0.02198156]
#  [0.6764683 ]
#  [0.66339624]
#  [0.65121204]] 0.46919256
# 9700 [[0.02259654]
#  [0.6806069 ]
#  [0.66347516]
#  [0.64841855]] 0.46580097
# 9800 [[0.0235142 ]
#  [0.68621534]
#  [0.6633989 ]
#  [0.64477026]] 0.46143204
# 9900 [[0.02485776]
#  [0.6937398 ]
#  [0.66308975]
#  [0.6399366 ]] 0.45578763
# 10000 [[0.02679244]
#  [0.70348823]
#  [0.6625372 ]
#  [0.6334682 ]] 0.44855264
# C_val: 0.4484713
# , Expected: [[0.]
#  [1.]
#  [1.]
#  [1.]] ,
#  Accuracy: 0.75
