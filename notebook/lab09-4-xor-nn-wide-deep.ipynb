# %%
import tensorflow as tf
import numpy as np
# Out:
# /Users/seongjuhyeon/workspace/tensorflowZeroToAll/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
tf.set_random_seed(777)

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# Variable1
W1 = tf.Variable(tf.random_normal([2,10]), name="weight1")
b1 = tf.Variable(tf.random_normal([10]), name="bias1")

layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

# %%
# Variable2
W2 = tf.Variable(tf.random_normal([10,10]), name="weight2")
b2 = tf.Variable(tf.random_normal([10]), name="bias2")

layer2 = tf.sigmoid(tf.matmul(layer1, W2) + b2)

# %%
# Variable3
W3 = tf.Variable(tf.random_normal([10,10]), name="weight3")
b3 = tf.Variable(tf.random_normal([10]), name="bias3")

layer3 = tf.sigmoid(tf.matmul(layer2, W3) + b3)

# %%
# Variable34
W4 = tf.Variable(tf.random_normal([10,1]), name="weight4")
b4 = tf.Variable(tf.random_normal([1]), name="bias4")

# %%
# hypothesis
hypothesis = tf.sigmoid(tf.matmul(layer3, W4) + b4)

# %%
# Cost
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1-Y) * tf.log(1-hypothesis))

# %%
# Minimize Cost
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
# Accuracy
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y, predicted), dtype=tf.float32))

# %%
# Fit the train
with tf.Session() as session:
    session.run(tf.global_variables_initializer())
    
    for step in range(1, 10001):
        _, cost_val, hypothesis_val = session.run([train, cost, hypothesis],
                                                  feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, hypothesis_val, cost_val)
    
    h_val, p_val, a_val = session.run([hypothesis, predicted, accuracy],
                                      feed_dict = {X: x_data, Y: y_data})
    print("H:", h_val, "\nPredicted:", p_val, "\nAccuracy:", a_val)
# Out:
# 100 [[0.48633373]
#  [0.5131347 ]
#  [0.49006298]
#  [0.5090555 ]] 0.68951094
# 200 [[0.48154497]
#  [0.51519436]
#  [0.49001896]
#  [0.51135105]] 0.68738383
# 300 [[0.47649443]
#  [0.51777196]
#  [0.48971933]
#  [0.51373583]] 0.6850885
# 400 [[0.47099626]
#  [0.5210081 ]
#  [0.48917982]
#  [0.51625127]] 0.68249106
# 500 [[0.464844  ]
#  [0.5251059 ]
#  [0.48838475]
#  [0.51892966]] 0.67943645
# 600 [[0.45778826]
#  [0.53035533]
#  [0.48728713]
#  [0.5217893 ]] 0.6757281
# 700 [[0.44950894]
#  [0.5371608 ]
#  [0.4858115 ]
#  [0.52482665]] 0.6711031
# 800 [[0.43958563]
#  [0.5460672 ]
#  [0.48387572]
#  [0.52800196]] 0.66519994
# 900 [[0.4274764 ]
#  [0.55776733]
#  [0.4814495 ]
#  [0.5312106 ]] 0.65751755
# 1000 [[0.41249573]
#  [0.5730913 ]
#  [0.47867376]
#  [0.53423697]] 0.64734906
# 1100 [[0.39375934]
#  [0.59302735]
#  [0.47603905]
#  [0.5366898 ]] 0.63365173
# 1200 [[0.37005126]
#  [0.6187708 ]
#  [0.4746658 ]
#  [0.537876  ]] 0.6148009
# 1300 [[0.33979425]
#  [0.65125716]
#  [0.47699496]
#  [0.5363642 ]] 0.58823997
# 1400 [[0.30220002]
#  [0.6887801 ]
#  [0.488195  ]
#  [0.5282852 ]] 0.55026925
# 1500 [[0.26050162]
#  [0.7259963 ]
#  [0.51557964]
#  [0.504037  ]] 0.49642774
# 1600 [[0.21974608]
#  [0.76264405]
#  [0.56445897]
#  [0.45286733]] 0.42351282
# 1700 [[0.17884271]
#  [0.8032159 ]
#  [0.6368687 ]
#  [0.3754681 ]] 0.33452925
# 1800 [[0.13666604]
#  [0.84714246]
#  [0.72330815]
#  [0.2856258 ]] 0.24327712
# 1900 [[0.09850892]
#  [0.88822234]
#  [0.802266  ]
#  [0.20455912]] 0.16785303
# 2000 [[0.06966119]
#  [0.9203268 ]
#  [0.8605905 ]
#  [0.1444728 ]] 0.11535168
# 2100 [[0.05014309]
#  [0.94258034]
#  [0.89946574]
#  [0.10414611]] 0.08162759
# 2200 [[0.0373373 ]
#  [0.95737314]
#  [0.924855  ]
#  [0.07768863]] 0.06015124
# 2300 [[0.02881554]
#  [0.96726906]
#  [0.9417653 ]
#  [0.06003737]] 0.046107937
# 2400 [[0.02296539]
#  [0.9740669 ]
#  [0.9534095 ]
#  [0.04788524]] 0.03657224
# 2500 [[0.01880851]
#  [0.9788889 ]
#  [0.9617141 ]
#  [0.03922902]] 0.029845504
# 2600 [[0.01575712]
#  [0.982418  ]
#  [0.9678326 ]
#  [0.03286242]] 0.02493291
# 2700 [[0.01345136]
#  [0.9850751 ]
#  [0.97247195]
#  [0.02804444]] 0.021234818
# 2800 [[0.0116646 ]
#  [0.9871265 ]
#  [0.9760785 ]
#  [0.02430679]] 0.018377392
# 2900 [[0.01024937]
#  [0.9887449 ]
#  [0.97894317]
#  [0.02134389]] 0.016119454
# 3000 [[0.00910706]
#  [0.99004644]
#  [0.98126113]
#  [0.01895102]] 0.014300434
# 3100 [[0.00816978]
#  [0.9911103 ]
#  [0.98316747]
#  [0.01698703]] 0.012810379
# 3200 [[0.00738965]
#  [0.9919927 ]
#  [0.9847573 ]
#  [0.01535197]] 0.011571923
# 3300 [[0.00673211]
#  [0.99273384]
#  [0.98609966]
#  [0.01397374]] 0.010529419
# 3400 [[0.00617174]
#  [0.9933635 ]
#  [0.9872457 ]
#  [0.0127992 ]] 0.00964192
# 3500 [[0.00568944]
#  [0.9939036 ]
#  [0.9882334 ]
#  [0.01178839]] 0.00887889
# 3600 [[0.00527068]
#  [0.99437124]
#  [0.9890921 ]
#  [0.0109109 ]] 0.008216992
# 3700 [[0.00490424]
#  [0.9947791 ]
#  [0.98984444]
#  [0.0101432 ]] 0.0076383334
# 3800 [[0.00458127]
#  [0.99513775]
#  [0.9905083 ]
#  [0.00946679]] 0.007128696
# 3900 [[0.00429483]
#  [0.9954549 ]
#  [0.9910977 ]
#  [0.00886699]] 0.00667705
# 4000 [[0.00403927]
#  [0.9957372 ]
#  [0.99162394]
#  [0.00833212]] 0.0062744403
# 4100 [[0.00381006]
#  [0.99598974]
#  [0.9920964 ]
#  [0.00785251]] 0.005913527
# 4200 [[0.00360347]
#  [0.9962167 ]
#  [0.99252254]
#  [0.00742042]] 0.0055885185
# 4300 [[0.00341646]
#  [0.9964218 ]
#  [0.9929086 ]
#  [0.00702943]] 0.0052944585
# 4400 [[0.00324646]
#  [0.9966079 ]
#  [0.9932596 ]
#  [0.00667414]] 0.0050273314
# 4500 [[0.00309134]
#  [0.99677724]
#  [0.99358034]
#  [0.00635008]] 0.004783698
# 4600 [[0.00294929]
#  [0.9969319 ]
#  [0.993874  ]
#  [0.00605348]] 0.004560783
# 4700 [[0.0028188 ]
#  [0.9970739 ]
#  [0.994144  ]
#  [0.00578111]] 0.004356071
# 4800 [[0.00269856]
#  [0.99720436]
#  [0.9943929 ]
#  [0.00553022]] 0.0041675586
# 4900 [[0.00258743]
#  [0.9973247 ]
#  [0.99462306]
#  [0.00529847]] 0.0039934237
# 5000 [[0.00248446]
#  [0.9974361 ]
#  [0.99483633]
#  [0.00508387]] 0.003832148
# 5100 [[0.00238883]
#  [0.9975394 ]
#  [0.9950346 ]
#  [0.00488458]] 0.0036824218
# 5200 [[0.00229979]
#  [0.99763525]
#  [0.9952192 ]
#  [0.00469914]] 0.0035431325
# 5300 [[0.00221671]
#  [0.9977247 ]
#  [0.9953916 ]
#  [0.0045262 ]] 0.0034131384
# 5400 [[0.00213902]
#  [0.99780816]
#  [0.9955527 ]
#  [0.00436453]] 0.0032917182
# 5500 [[0.00206625]
#  [0.9978861 ]
#  [0.99570376]
#  [0.00421317]] 0.0031780154
# 5600 [[0.00199794]
#  [0.99795926]
#  [0.9958456 ]
#  [0.00407118]] 0.0030713244
# 5700 [[0.00193372]
#  [0.998028  ]
#  [0.99597895]
#  [0.00393771]] 0.0029710454
# 5800 [[0.00187323]
#  [0.9980925 ]
#  [0.9961046 ]
#  [0.00381208]] 0.0028766822
# 5900 [[0.00181618]
#  [0.99815327]
#  [0.9962231 ]
#  [0.0036936 ]] 0.00278768
# 6000 [[0.00176228]
#  [0.99821067]
#  [0.99633515]
#  [0.00358174]] 0.0027036339
# 6100 [[0.0017113 ]
#  [0.99826497]
#  [0.99644107]
#  [0.00347599]] 0.0026241536
# 6200 [[0.001663  ]
#  [0.99831617]
#  [0.99654156]
#  [0.00337584]] 0.0025489093
# 6300 [[0.00161719]
#  [0.99836475]
#  [0.99663675]
#  [0.00328087]] 0.0024775716
# 6400 [[0.00157368]
#  [0.9984108 ]
#  [0.9967272 ]
#  [0.00319073]] 0.0024098402
# 6500 [[0.00153232]
#  [0.9984546 ]
#  [0.99681336]
#  [0.00310507]] 0.0023454307
# 6600 [[0.00149294]
#  [0.9984962 ]
#  [0.9968952 ]
#  [0.00302357]] 0.002284193
# 6700 [[0.00145543]
#  [0.99853575]
#  [0.9969733 ]
#  [0.00294593]] 0.0022258572
# 6800 [[0.00141964]
#  [0.9985734 ]
#  [0.99704784]
#  [0.00287186]] 0.0021701988
# 6900 [[0.00138546]
#  [0.9986094 ]
#  [0.99711895]
#  [0.0028012 ]] 0.0021170685
# 7000 [[0.0013528 ]
#  [0.9986438 ]
#  [0.99718684]
#  [0.00273371]] 0.002066346
# 7100 [[0.00132157]
#  [0.9986766 ]
#  [0.9972519 ]
#  [0.00266917]] 0.0020178217
# 7200 [[0.00129164]
#  [0.998708  ]
#  [0.9973143 ]
#  [0.00260741]] 0.0019713605
# 7300 [[0.00126298]
#  [0.9987381 ]
#  [0.99737394]
#  [0.00254822]] 0.0019268583
# 7400 [[0.00123548]
#  [0.9987669 ]
#  [0.9974312 ]
#  [0.00249148]] 0.0018841949
# 7500 [[0.00120909]
#  [0.99879444]
#  [0.9974861 ]
#  [0.00243705]] 0.0018432956
# 7600 [[0.00118375]
#  [0.99882084]
#  [0.9975389 ]
#  [0.00238477]] 0.0018040107
# 7700 [[0.00115939]
#  [0.9988463 ]
#  [0.9975897 ]
#  [0.00233456]] 0.0017662206
# 7800 [[0.00113595]
#  [0.9988707 ]
#  [0.99763846]
#  [0.00228628]] 0.0017299401
# 7900 [[0.0011134 ]
#  [0.9988943 ]
#  [0.99768543]
#  [0.00223981]] 0.0016949896
# 8000 [[0.00109166]
#  [0.99891686]
#  [0.9977308 ]
#  [0.00219509]] 0.0016613095
# 8100 [[0.00107073]
#  [0.9989386 ]
#  [0.9977744 ]
#  [0.00215202]] 0.0016289144
# 8200 [[0.00105052]
#  [0.99895966]
#  [0.99781644]
#  [0.00211044]] 0.0015976402
# 8300 [[0.00103104]
#  [0.99897975]
#  [0.99785703]
#  [0.00207033]] 0.0015675164
# 8400 [[0.00101222]
#  [0.9989993 ]
#  [0.9978962 ]
#  [0.00203167]] 0.0015384236
# 8500 [[9.940474e-04]
#  [9.990182e-01]
#  [9.979341e-01]
#  [1.994293e-03]] 0.001510287
# 8600 [[9.7648473e-04]
#  [9.9903643e-01]
#  [9.9797076e-01]
#  [1.9582130e-03]] 0.0014831065
# 8700 [[9.5950236e-04]
#  [9.9905390e-01]
#  [9.9800617e-01]
#  [1.9233156e-03]] 0.0014568821
# 8800 [[9.4305305e-04]
#  [9.9907088e-01]
#  [9.9804050e-01]
#  [1.8895809e-03]] 0.0014314645
# 8900 [[9.2714292e-04]
#  [9.9908733e-01]
#  [9.9807358e-01]
#  [1.8569344e-03]] 0.0014068983
# 9000 [[9.1172848e-04]
#  [9.9910331e-01]
#  [9.9810576e-01]
#  [1.8253045e-03]] 0.0013830638
# 9100 [[8.9679327e-04]
#  [9.9911863e-01]
#  [9.9813688e-01]
#  [1.7946766e-03]] 0.0013600362
# 9200 [[8.8231376e-04]
#  [9.9913353e-01]
#  [9.9816704e-01]
#  [1.7649796e-03]] 0.0013376805
# 9300 [[8.6827425e-04]
#  [9.9914801e-01]
#  [9.9819630e-01]
#  [1.7362077e-03]] 0.0013160119
# 9400 [[8.5464644e-04]
#  [9.9916208e-01]
#  [9.9822479e-01]
#  [1.7083220e-03]] 0.0012949705
# 9500 [[8.4141712e-04]
#  [9.9917561e-01]
#  [9.9825221e-01]
#  [1.6812186e-03]] 0.0012746161
# 9600 [[8.2857761e-04]
#  [9.9918884e-01]
#  [9.9827909e-01]
#  [1.6549274e-03]] 0.0012547695
# 9700 [[8.1610988e-04]
#  [9.9920160e-01]
#  [9.9830508e-01]
#  [1.6293981e-03]] 0.0012355649
# 9800 [[8.0397679e-04]
#  [9.9921405e-01]
#  [9.9833041e-01]
#  [1.6045903e-03]] 0.0012168533
# 9900 [[7.9219748e-04]
#  [9.9922609e-01]
#  [9.9835485e-01]
#  [1.5804906e-03]] 0.0011987388
# 10000 [[7.8073685e-04]
#  [9.9923790e-01]
#  [9.9837875e-01]
#  [1.5570498e-03]] 0.0011810723
# H: [[7.8062405e-04]
#  [9.9923801e-01]
#  [9.9837899e-01]
#  [1.5568215e-03]]
# Predicted: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Accuracy: 1.0
