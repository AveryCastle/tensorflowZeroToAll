# %%
import tensorflow as tf
import numpy as np

# %%
tf.set_random_seed(777)

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# Variable1
W1 = tf.Variable(tf.random_normal([2,10]), name="weight1")
b1 = tf.Variable(tf.random_normal([10]), name="bias1")

layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

# %%
# Variable2
W2 = tf.Variable(tf.random_normal([10,10]), name="weight2")
b2 = tf.Variable(tf.random_normal([10]), name="bias2")

layer2 = tf.sigmoid(tf.matmul(layer1, W2) + b2)

# %%
# Variable3
W3 = tf.Variable(tf.random_normal([10,10]), name="weight3")
b3 = tf.Variable(tf.random_normal([10]), name="bias3")

layer3 = tf.sigmoid(tf.matmul(layer2, W3) + b3)

# %%
# Variable34
W4 = tf.Variable(tf.random_normal([10,1]), name="weight4")
b4 = tf.Variable(tf.random_normal([1]), name="bias4")

# %%
# hypothesis
hypothesis = tf.sigmoid(tf.matmul(layer3, W4) + b4)

# %%
# Cost
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1-Y) * tf.log(1-hypothesis))

# %%
# Minimize Cost
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
# Accuracy
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y, predicted), dtype=tf.float32))

# %%
# Fit the train
with tf.Session() as session:
    session.run(tf.global_variables_initializer())
    
    for step in range(1, 10001):
        _, cost_val, hypothesis_val = session.run([train, cost, hypothesis],
                                                  feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, hypothesis_val, cost_val)
    
    h_val, p_val, a_val = session.run([hypothesis, predicted, accuracy],
                                      feed_dict = {X: x_data, Y: y_data})
    print("H:", h_val, "\nPredicted:", p_val, "\nAccuracy:", a_val)
# Out:
# 100 [[0.4421735 ]
#  [0.47055644]
#  [0.56663835]
#  [0.5021897 ]] 0.6507792
# 200 [[0.4014955]
#  [0.463363 ]
#  [0.6180019]
#  [0.5109406]] 0.6197752
# 300 [[0.3660635 ]
#  [0.45601544]
#  [0.67106223]
#  [0.50895876]] 0.58778894
# 400 [[0.33549133]
#  [0.45849535]
#  [0.718112  ]
#  [0.49843284]] 0.552415
# 500 [[0.30261147]
#  [0.47939324]
#  [0.75625753]
#  [0.48215023]] 0.5082725
# 600 [[0.26342064]
#  [0.5334397 ]
#  [0.78107774]
#  [0.45034984]] 0.44492534
# 700 [[0.22010873]
#  [0.6277683 ]
#  [0.7995509 ]
#  [0.3799958 ]] 0.35397977
# 800 [[0.17727305]
#  [0.73417205]
#  [0.83117926]
#  [0.28011477]] 0.254429
# 900 [[0.13500774]
#  [0.8160107 ]
#  [0.8720742 ]
#  [0.19684613]] 0.17611307
# 1000 [[0.09987056]
#  [0.86961544]
#  [0.90628046]
#  [0.1413828 ]] 0.12393987
# 1100 [[0.07485645]
#  [0.90389264]
#  [0.9302711 ]
#  [0.10537639]] 0.09062062
# 1200 [[0.05779323]
#  [0.9262776 ]
#  [0.9464806 ]
#  [0.0815043 ]] 0.069033675
# 1300 [[0.04601784]
#  [0.94143516]
#  [0.95759237]
#  [0.06513894]] 0.054537635
# 1400 [[0.03765628]
#  [0.9521017 ]
#  [0.96544117]
#  [0.0535106 ]] 0.04440817
# 1500 [[0.03153079]
#  [0.95988053]
#  [0.9711656 ]
#  [0.04496605]] 0.037062928
# 1600 [[0.02691109]
#  [0.9657339 ]
#  [0.9754665 ]
#  [0.03849804]] 0.031561233
# 1700 [[0.02333624]
#  [0.97025865]
#  [0.9787835 ]
#  [0.03347431]] 0.027324416
# 1800 [[0.02050735]
#  [0.9738376 ]
#  [0.9814005 ]
#  [0.02948492]] 0.02398356
# 1900 [[0.01822516]
#  [0.9767249 ]
#  [0.98350614]
#  [0.02625616]] 0.021295466
# 2000 [[0.0163529 ]
#  [0.9790943 ]
#  [0.98522943]
#  [0.02359957]] 0.01909465
# 2100 [[0.01479441]
#  [0.9810672 ]
#  [0.9866607 ]
#  [0.0213824 ]] 0.017265657
# 2200 [[0.01348048]
#  [0.9827313 ]
#  [0.98786503]
#  [0.0195087 ]] 0.015725615
# 2300 [[0.01236027]
#  [0.98415065]
#  [0.98888993]
#  [0.0179079 ]] 0.014414011
# 2400 [[0.01139569]
#  [0.9853736 ]
#  [0.9897709 ]
#  [0.01652682]] 0.013285555
# 2500 [[0.01055778]
#  [0.98643655]
#  [0.99053496]
#  [0.01532502]] 0.012305987
# 2600 [[0.00982412]
#  [0.9873677 ]
#  [0.99120295]
#  [0.01427109]] 0.011448828
# 2700 [[0.00917719]
#  [0.98818934]
#  [0.99179125]
#  [0.01334041]] 0.0106933415
# 2800 [[0.00860307]
#  [0.98891884]
#  [0.9923126 ]
#  [0.01251342]] 0.010023177
# 2900 [[0.00809059]
#  [0.9895704 ]
#  [0.99277747]
#  [0.01177435]] 0.009425221
# 3000 [[0.00763072]
#  [0.99015546]
#  [0.993194  ]
#  [0.0111104 ]] 0.008888794
# 3100 [[0.00721605]
#  [0.9906833 ]
#  [0.99356925]
#  [0.01051112]] 0.008405199
# 3200 [[0.00684048]
#  [0.9911616 ]
#  [0.99390876]
#  [0.00996786]] 0.007967355
# 3300 [[0.00649893]
#  [0.99159676]
#  [0.9942173 ]
#  [0.00947338]] 0.007569235
# 3400 [[0.00618715]
#  [0.99199426]
#  [0.99449867]
#  [0.00902167]] 0.007205869
# 3500 [[0.00590152]
#  [0.9923585 ]
#  [0.9947561 ]
#  [0.00860756]] 0.00687309
# 3600 [[0.00563906]
#  [0.9926934 ]
#  [0.99499243]
#  [0.00822676]] 0.00656734
# 3700 [[0.00539711]
#  [0.99300236]
#  [0.99521023]
#  [0.00787551]] 0.0062854746
# 3800 [[0.00517345]
#  [0.9932881 ]
#  [0.99541134]
#  [0.00755064]] 0.006024983
# 3900 [[0.00496617]
#  [0.9935529 ]
#  [0.99559766]
#  [0.00724939]] 0.005783585
# 4000 [[0.00477358]
#  [0.99379915]
#  [0.9957705 ]
#  [0.00696935]] 0.0055593327
# 4100 [[0.00459424]
#  [0.99402857]
#  [0.99593157]
#  [0.00670846]] 0.005350476
# 4200 [[0.00442686]
#  [0.9942427 ]
#  [0.99608165]
#  [0.00646486]] 0.0051556113
# 4300 [[0.00427033]
#  [0.99444324]
#  [0.9962219 ]
#  [0.00623699]] 0.0049733683
# 4400 [[0.00412366]
#  [0.99463105]
#  [0.9963534 ]
#  [0.00602338]] 0.0048026163
# 4500 [[0.00398597]
#  [0.99480754]
#  [0.9964766 ]
#  [0.00582277]] 0.004642345
# 4600 [[0.00385649]
#  [0.9949734 ]
#  [0.99659234]
#  [0.00563407]] 0.004491667
# 4700 [[0.00373455]
#  [0.9951298 ]
#  [0.9967014 ]
#  [0.0054563 ]] 0.004349709
# 4800 [[0.00361952]
#  [0.9952774 ]
#  [0.99680424]
#  [0.00528854]] 0.0042158235
# 4900 [[0.00351084]
#  [0.9954169 ]
#  [0.9969014 ]
#  [0.00512999]] 0.0040893196
# 5000 [[0.00340803]
#  [0.99554884]
#  [0.9969932 ]
#  [0.00498   ]] 0.003969685
# 5100 [[0.00331062]
#  [0.99567395]
#  [0.99708   ]
#  [0.00483785]] 0.0038563493
# 5200 [[0.00321823]
#  [0.99579275]
#  [0.9971624 ]
#  [0.00470299]] 0.003748816
# 5300 [[0.0031305 ]
#  [0.9959055 ]
#  [0.9972408 ]
#  [0.00457489]] 0.003646679
# 5400 [[0.00304707]
#  [0.9960128 ]
#  [0.9973151 ]
#  [0.00445307]] 0.0035495935
# 5500 [[0.00296766]
#  [0.99611485]
#  [0.9973858 ]
#  [0.00433709]] 0.0034572282
# 5600 [[0.00289199]
#  [0.99621236]
#  [0.9974533 ]
#  [0.00422655]] 0.0033691335
# 5700 [[0.0028198 ]
#  [0.9963052 ]
#  [0.99751747]
#  [0.00412108]] 0.0032851438
# 5800 [[0.00275089]
#  [0.996394  ]
#  [0.9975788 ]
#  [0.00402036]] 0.003204944
# 5900 [[0.00268503]
#  [0.99647886]
#  [0.9976374 ]
#  [0.00392409]] 0.003128294
# 6000 [[0.00262202]
#  [0.9965599 ]
#  [0.99769336]
#  [0.00383199]] 0.0030550282
# 6100 [[0.0025617 ]
#  [0.9966377 ]
#  [0.997747  ]
#  [0.00374381]] 0.0029848323
# 6200 [[0.0025039 ]
#  [0.9967123 ]
#  [0.9977984 ]
#  [0.00365931]] 0.002917556
# 6300 [[0.00244848]
#  [0.99678373]
#  [0.9978477 ]
#  [0.00357827]] 0.0028530643
# 6400 [[0.00239529]
#  [0.99685246]
#  [0.9978948 ]
#  [0.00350048]] 0.0027911626
# 6500 [[0.0023442 ]
#  [0.9969183 ]
#  [0.99794024]
#  [0.00342577]] 0.0027317302
# 6600 [[0.00229508]
#  [0.9969817 ]
#  [0.9979838 ]
#  [0.00335392]] 0.002674603
# 6700 [[0.00224786]
#  [0.9970427 ]
#  [0.99802566]
#  [0.00328484]] 0.00261966
# 6800 [[0.00220241]
#  [0.9971015 ]
#  [0.998066  ]
#  [0.00321836]] 0.0025667376
# 6900 [[0.00215863]
#  [0.99715805]
#  [0.9981048 ]
#  [0.00315431]] 0.0025158203
# 7000 [[0.00211644]
#  [0.9972126 ]
#  [0.99814224]
#  [0.00309259]] 0.002466713
# 7100 [[0.00207577]
#  [0.9972652 ]
#  [0.99817824]
#  [0.00303308]] 0.002419401
# 7200 [[0.00203651]
#  [0.99731594]
#  [0.99821305]
#  [0.00297563]] 0.0023737196
# 7300 [[0.00199862]
#  [0.99736506]
#  [0.99824667]
#  [0.00292017]] 0.0023295786
# 7400 [[0.00196201]
#  [0.9974124 ]
#  [0.998279  ]
#  [0.00286659]] 0.0022870232
# 7500 [[0.00192665]
#  [0.9974583 ]
#  [0.9983103 ]
#  [0.00281482]] 0.0022458439
# 7600 [[0.00189244]
#  [0.9975025 ]
#  [0.9983406 ]
#  [0.00276477]] 0.002206055
# 7700 [[0.00185936]
#  [0.9975453 ]
#  [0.9983699 ]
#  [0.00271635]] 0.0021675825
# 7800 [[0.00182731]
#  [0.99758685]
#  [0.99839824]
#  [0.00266944]] 0.002130276
# 7900 [[0.00179631]
#  [0.9976271 ]
#  [0.9984257 ]
#  [0.00262406]] 0.002094166
# 8000 [[0.00176628]
#  [0.997666  ]
#  [0.9984522 ]
#  [0.00258007]] 0.0020592366
# 8100 [[0.00173715]
#  [0.99770385]
#  [0.998478  ]
#  [0.00253744]] 0.002025324
# 8200 [[0.00170891]
#  [0.9977405 ]
#  [0.99850297]
#  [0.00249611]] 0.001992458
# 8300 [[0.00168151]
#  [0.997776  ]
#  [0.99852717]
#  [0.00245598]] 0.0019605933
# 8400 [[0.00165492]
#  [0.99781054]
#  [0.9985506 ]
#  [0.00241705]] 0.0019296408
# 8500 [[0.0016291 ]
#  [0.997844  ]
#  [0.9985734 ]
#  [0.00237925]] 0.0018996147
# 8600 [[0.00160403]
#  [0.9978765 ]
#  [0.99859554]
#  [0.00234253]] 0.0018704408
# 8700 [[0.00157969]
#  [0.99790823]
#  [0.99861705]
#  [0.00230691]] 0.0018421037
# 8800 [[0.00155598]
#  [0.99793893]
#  [0.998638  ]
#  [0.00227216]] 0.0018145139
# 8900 [[0.00153297]
#  [0.997969  ]
#  [0.9986583 ]
#  [0.00223848]] 0.0017877012
# 9000 [[0.00151057]
#  [0.99799806]
#  [0.998678  ]
#  [0.00220566]] 0.0017616506
# 9100 [[0.00148877]
#  [0.9980263 ]
#  [0.99869734]
#  [0.00217375]] 0.0017362724
# 9200 [[0.00146758]
#  [0.998054  ]
#  [0.998716  ]
#  [0.00214271]] 0.0017115966
# 9300 [[0.00144691]
#  [0.99808085]
#  [0.9987343 ]
#  [0.00211246]] 0.0016875335
# 9400 [[0.0014268]
#  [0.9981071]
#  [0.998752 ]
#  [0.002083 ]] 0.0016641277
# 9500 [[0.00140721]
#  [0.99813265]
#  [0.9987692 ]
#  [0.00205432]] 0.0016413194
# 9600 [[0.0013881 ]
#  [0.99815744]
#  [0.99878615]
#  [0.00202631]] 0.0016190641
# 9700 [[0.00136949]
#  [0.9981817 ]
#  [0.99880254]
#  [0.00199907]] 0.0015974063
# 9800 [[0.00135131]
#  [0.9982053 ]
#  [0.99881846]
#  [0.00197243]] 0.0015762864
# 9900 [[0.00133359]
#  [0.9982284 ]
#  [0.9988341 ]
#  [0.00194649]] 0.0015556742
# 10000 [[0.00131631]
#  [0.9982509 ]
#  [0.9988493 ]
#  [0.00192118]] 0.0015355551
# H: [[0.00131614]
#  [0.99825114]
#  [0.9988495 ]
#  [0.00192093]]
# Predicted: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Accuracy: 1.0
