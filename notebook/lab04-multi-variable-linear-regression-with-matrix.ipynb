# %%
import tensorflow as tf

# %%
# x and y data(x_train, y_train)
x_train = [[73., 80., 75.],
            [93., 88., 93.],
            [89., 91., 90.],
            [96., 98., 100.],
            [73., 66., 70.]]
y_train = [[152.], [185.], [180.], [196.], [142.]]

# %%
# placeholder
X = tf.placeholder(tf.float32, shape = [None, 3])
Y = tf.placeholder(tf.float32, shape = [None, 1])

# %%
# Variables
W = tf.Variable(tf.random_normal([3, 1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# %%
# hypothesis
hypothesis = tf.matmul(X, W) + b

# %%
# cost
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# minimize cost
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 1e-5)
train = optimizer.minimize(cost)

# %%
# prepare session
session = tf.Session()
session.run(tf.global_variables_initializer())

# %%
for step in range(10001):
    cost_val, hypothesis_val, _ = session.run([cost, hypothesis, train], feed_dict = {X: x_train, Y: y_train})
    if step % 200 == 0:
        print(step, "Cost: ", cost_val, "\n Prediction: ", hypothesis_val)
# Out:
# 0 Cost:  0.3028465
#  Prediction:  [[151.76387]
#  [184.41626]
#  [180.5864 ]
#  [196.62717]
#  [141.38313]]
# 200 Cost:  0.29302883
#  Prediction:  [[151.74242]
#  [184.4312 ]
#  [180.58015]
#  [196.6201 ]
#  [141.40489]]
# 400 Cost:  0.28413936
#  Prediction:  [[151.72218]
#  [184.44536]
#  [180.57426]
#  [196.61333]
#  [141.4256 ]]
# 600 Cost:  0.27611095
#  Prediction:  [[151.70305]
#  [184.45871]
#  [180.56873]
#  [196.6068 ]
#  [141.44527]]
# 800 Cost:  0.26884285
#  Prediction:  [[151.685  ]
#  [184.47134]
#  [180.5635 ]
#  [196.60052]
#  [141.46396]]
# 1000 Cost:  0.26226425
#  Prediction:  [[151.66794]
#  [184.48328]
#  [180.5586 ]
#  [196.5945 ]
#  [141.48174]]
# 1200 Cost:  0.2562936
#  Prediction:  [[151.65184]
#  [184.49457]
#  [180.55399]
#  [196.58867]
#  [141.49864]]
# 1400 Cost:  0.25087392
#  Prediction:  [[151.63664]
#  [184.50523]
#  [180.54964]
#  [196.58307]
#  [141.51474]]
# 1600 Cost:  0.24595436
#  Prediction:  [[151.62231]
#  [184.51532]
#  [180.54556]
#  [196.57767]
#  [141.53003]]
# 1800 Cost:  0.24147716
#  Prediction:  [[151.60878]
#  [184.52483]
#  [180.54173]
#  [196.57243]
#  [141.5446 ]]
# 2000 Cost:  0.23740092
#  Prediction:  [[151.59604]
#  [184.53383]
#  [180.53813]
#  [196.56741]
#  [141.55846]]
# 2200 Cost:  0.23368964
#  Prediction:  [[151.58398]
#  [184.54231]
#  [180.53474]
#  [196.56255]
#  [141.57164]]
# 2400 Cost:  0.2302994
#  Prediction:  [[151.57265]
#  [184.55034]
#  [180.53159]
#  [196.55786]
#  [141.58421]]
# 2600 Cost:  0.22718994
#  Prediction:  [[151.56195]
#  [184.55792]
#  [180.52861]
#  [196.5533 ]
#  [141.59619]]
# 2800 Cost:  0.2243505
#  Prediction:  [[151.55188]
#  [184.56506]
#  [180.52582]
#  [196.54892]
#  [141.6076 ]]
# 3000 Cost:  0.2217503
#  Prediction:  [[151.54237]
#  [184.57181]
#  [180.52322]
#  [196.54465]
#  [141.61845]]
# 3200 Cost:  0.21934906
#  Prediction:  [[151.53345]
#  [184.57819]
#  [180.52077]
#  [196.54053]
#  [141.62881]]
# 3400 Cost:  0.2171567
#  Prediction:  [[151.52502]
#  [184.5842 ]
#  [180.5185 ]
#  [196.53656]
#  [141.63867]]
# 3600 Cost:  0.21511655
#  Prediction:  [[151.51709]
#  [184.58987]
#  [180.51636]
#  [196.53265]
#  [141.6481 ]]
# 3800 Cost:  0.21324536
#  Prediction:  [[151.50964]
#  [184.5952 ]
#  [180.51437]
#  [196.5289 ]
#  [141.65707]]
# 4000 Cost:  0.21150967
#  Prediction:  [[151.50264]
#  [184.60025]
#  [180.51254]
#  [196.52525]
#  [141.66565]]
# 4200 Cost:  0.20989776
#  Prediction:  [[151.49605]
#  [184.605  ]
#  [180.5108 ]
#  [196.52171]
#  [141.67383]]
# 4400 Cost:  0.20839432
#  Prediction:  [[151.48985]
#  [184.60947]
#  [180.5092 ]
#  [196.51823]
#  [141.68164]]
# 4600 Cost:  0.20699391
#  Prediction:  [[151.48404]
#  [184.6137 ]
#  [180.5077 ]
#  [196.51488]
#  [141.6891 ]]
# 4800 Cost:  0.20568931
#  Prediction:  [[151.47859]
#  [184.61766]
#  [180.50633]
#  [196.51161]
#  [141.69623]]
# 5000 Cost:  0.20446482
#  Prediction:  [[151.47346]
#  [184.62138]
#  [180.50504]
#  [196.50842]
#  [141.70305]]
# 5200 Cost:  0.20331666
#  Prediction:  [[151.46867]
#  [184.62491]
#  [180.50386]
#  [196.50533]
#  [141.70956]]
# 5400 Cost:  0.20223418
#  Prediction:  [[151.4642 ]
#  [184.62823]
#  [180.50278]
#  [196.50233]
#  [141.71582]]
# 5600 Cost:  0.20121098
#  Prediction:  [[151.45998]
#  [184.63133]
#  [180.50175]
#  [196.49934]
#  [141.72177]]
# 5800 Cost:  0.20024896
#  Prediction:  [[151.45604]
#  [184.63426]
#  [180.50084]
#  [196.49648]
#  [141.7275 ]]
# 6000 Cost:  0.19933912
#  Prediction:  [[151.45235]
#  [184.637  ]
#  [180.49997]
#  [196.49367]
#  [141.73294]]
# 6200 Cost:  0.19846974
#  Prediction:  [[151.44891]
#  [184.63959]
#  [180.4992 ]
#  [196.49092]
#  [141.73819]]
# 6400 Cost:  0.19763947
#  Prediction:  [[151.4457 ]
#  [184.642  ]
#  [180.49849]
#  [196.4882 ]
#  [141.74321]]
# 6600 Cost:  0.19685142
#  Prediction:  [[151.44272]
#  [184.64427]
#  [180.49786]
#  [196.4856 ]
#  [141.74805]]
# 6800 Cost:  0.19609319
#  Prediction:  [[151.43994]
#  [184.64642]
#  [180.4973 ]
#  [196.48302]
#  [141.75267]]
# 7000 Cost:  0.19536826
#  Prediction:  [[151.43733]
#  [184.6484 ]
#  [180.49677]
#  [196.48047]
#  [141.7571 ]]
# 7200 Cost:  0.19467655
#  Prediction:  [[151.4349 ]
#  [184.65027]
#  [180.49629]
#  [196.478  ]
#  [141.76135]]
# 7400 Cost:  0.19400044
#  Prediction:  [[151.43268]
#  [184.65202]
#  [180.49588]
#  [196.47556]
#  [141.76546]]
# 7600 Cost:  0.1933544
#  Prediction:  [[151.43062]
#  [184.65366]
#  [180.49551]
#  [196.47319]
#  [141.7694 ]]
# 7800 Cost:  0.19273022
#  Prediction:  [[151.42871]
#  [184.65517]
#  [180.4952 ]
#  [196.47086]
#  [141.77318]]
# 8000 Cost:  0.19212449
#  Prediction:  [[151.42694]
#  [184.65659]
#  [180.49492]
#  [196.46855]
#  [141.77682]]
# 8200 Cost:  0.1915319
#  Prediction:  [[151.42534]
#  [184.65791]
#  [180.49469]
#  [196.4663 ]
#  [141.78033]]
# 8400 Cost:  0.19096097
#  Prediction:  [[151.42384]
#  [184.65915]
#  [180.49449]
#  [196.46408]
#  [141.78372]]
# 8600 Cost:  0.19040763
#  Prediction:  [[151.42247]
#  [184.6603 ]
#  [180.49435]
#  [196.46188]
#  [141.78699]]
# 8800 Cost:  0.1898638
#  Prediction:  [[151.42122]
#  [184.66136]
#  [180.49422]
#  [196.45973]
#  [141.79012]]
# 9000 Cost:  0.1893346
#  Prediction:  [[151.42009]
#  [184.66234]
#  [180.49413]
#  [196.45763]
#  [141.79317]]
# 9200 Cost:  0.18882176
#  Prediction:  [[151.41905]
#  [184.66325]
#  [180.49408]
#  [196.45554]
#  [141.79608]]
# 9400 Cost:  0.18831742
#  Prediction:  [[151.41812]
#  [184.6641 ]
#  [180.49403]
#  [196.4535 ]
#  [141.79892]]
# 9600 Cost:  0.1878227
#  Prediction:  [[151.41728]
#  [184.66489]
#  [180.49405]
#  [196.45148]
#  [141.80167]]
# 9800 Cost:  0.18734415
#  Prediction:  [[151.41653]
#  [184.66562]
#  [180.4941 ]
#  [196.44951]
#  [141.80432]]
# 10000 Cost:  0.18686426
#  Prediction:  [[151.41585]
#  [184.66628]
#  [180.49411]
#  [196.44751]
#  [141.80685]]
