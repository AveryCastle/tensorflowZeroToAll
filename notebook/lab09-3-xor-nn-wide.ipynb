# %%
import tensorflow as tf
import numpy as np
# Out:
# /Users/seongjuhyeon/workspace/tensorflowZeroToAll/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
tf.set_random_seed(777)

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None,2])
Y = tf.placeholder(tf.float32, shape=[None,1])

# %%
# Variables - 1
W1 = tf.Variable(tf.random_normal([2,10]), name="weight1")
b1 = tf.Variable(tf.random_normal([10]), name="bias1")

layer = tf.sigmoid(tf.matmul(X, W1) + b1)

# %%
# Variable - 2
W2 = tf.Variable(tf.random_normal([10, 1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')

# %%
# Hypothesis
hypothesis = tf.sigmoid(tf.matmul(layer, W2) + b2)

# %%
# Cost
cost = -tf.reduce_mean(Y*tf.log(hypothesis) + (1-Y)*tf.log(1-hypothesis))

# %%
# Minimize cost
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
# Accuracy
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
# Fit the train
with tf.Session() as session:
    session.run(tf.global_variables_initializer())
    
    for step in range(1, 10001):
        cost_val, hypothesis_val, _ = session.run([cost, hypothesis, train],
                                                  feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, hypothesis_val, cost_val)
    
    c_val, p_val, a_val = session.run([cost, predicted, accuracy],
                                      feed_dict={X: x_data, Y: y_data})
    print("C_val:", c_val, "\n, Expected:", p_val, ",\n Accuracy:", a_val)
# Out:
# 100 [[0.34902996]
#  [0.41713873]
#  [0.60070676]
#  [0.615255  ]] 0.69211274
# 200 [[0.36635116]
#  [0.4521483 ]
#  [0.59113705]
#  [0.5786294 ]] 0.6599888
# 300 [[0.36998987]
#  [0.4737588 ]
#  [0.594376  ]
#  [0.5541405 ]] 0.6342677
# 400 [[0.36310253]
#  [0.49192765]
#  [0.6041461 ]
#  [0.535508  ]] 0.60783005
# 500 [[0.34738982]
#  [0.51189595]
#  [0.61814237]
#  [0.5185407 ]] 0.5770948
# 600 [[0.324161  ]
#  [0.537066  ]
#  [0.63537174]
#  [0.4998346 ]] 0.53994906
# 700 [[0.2951361 ]
#  [0.56902367]
#  [0.6554573 ]
#  [0.47659123]] 0.4958496
# 800 [[0.26276585]
#  [0.60700625]
#  [0.67838526]
#  [0.4472723 ]] 0.44624892
# 900 [[0.22977069]
#  [0.6483892 ]
#  [0.7038544 ]
#  [0.41239277]] 0.39430285
# 1000 [[0.19841953]
#  [0.6899705 ]
#  [0.73079515]
#  [0.374291  ]] 0.34369206
# 1100 [[0.17017241]
#  [0.7290514 ]
#  [0.75769085]
#  [0.33590618]] 0.29733998
# 1200 [[0.14568785]
#  [0.7639768 ]
#  [0.78318584]
#  [0.2996211 ]] 0.2567989
# 1300 [[0.12501095]
#  [0.7941399 ]
#  [0.8064143 ]
#  [0.26681352]] 0.22238809
# 1400 [[0.10781729]
#  [0.81966877]
#  [0.82701176]
#  [0.23797369]] 0.19366246
# 1500 [[0.09362197]
#  [0.8410664 ]
#  [0.8449727 ]
#  [0.2130226 ]] 0.16984753
# 1600 [[0.08191617]
#  [0.85895556]
#  [0.86049557]
#  [0.19159703]] 0.15011153
# 1700 [[0.07223667]
#  [0.8739413 ]
#  [0.8738648 ]
#  [0.17323482]] 0.1336962
# 1800 [[0.06419079]
#  [0.8865547 ]
#  [0.8853812 ]
#  [0.15747474]] 0.11996118
# 1900 [[0.05745845]
#  [0.8972374 ]
#  [0.89532644]
#  [0.14389946]] 0.1083861
# 2000 [[0.05178392]
#  [0.9063475 ]
#  [0.90394795]
#  [0.13215084]] 0.09855655
# 2100 [[0.04696488]
#  [0.91417134]
#  [0.911457  ]
#  [0.12192859]] 0.090144746
# 2200 [[0.0428419 ]
#  [0.9209389 ]
#  [0.91803026]
#  [0.1129857 ]] 0.08289185
# 2300 [[0.03928865]
#  [0.9268319 ]
#  [0.923814  ]
#  [0.10511797]] 0.076593064
# 2400 [[0.03620533]
#  [0.9319968 ]
#  [0.9289291 ]
#  [0.09815899]] 0.07108571
# 2500 [[0.03351239]
#  [0.9365517 ]
#  [0.9334757 ]
#  [0.0919719 ]] 0.066239424
# 2600 [[0.03114592]
#  [0.9405912 ]
#  [0.937536  ]
#  [0.08644366]] 0.06194957
# 2700 [[0.02905439]
#  [0.94419277]
#  [0.94117856]
#  [0.08148123]] 0.05813127
# 2800 [[0.02719599]
#  [0.9474203 ]
#  [0.9444606 ]
#  [0.07700712]] 0.054715052
# 2900 [[0.02553629]
#  [0.95032585]
#  [0.9474297 ]
#  [0.07295622]] 0.05164384
# 3000 [[0.02404727]
#  [0.9529528 ]
#  [0.9501262 ]
#  [0.06927466]] 0.048870645
# 3100 [[0.02270552]
#  [0.95533735]
#  [0.9525838 ]
#  [0.06591664]] 0.0463562
# 3200 [[0.02149154]
#  [0.9575104 ]
#  [0.95483124]
#  [0.06284305]] 0.044067416
# 3300 [[0.02038897]
#  [0.95949733]
#  [0.9568932 ]
#  [0.06002105]] 0.041976675
# 3400 [[0.01938401]
#  [0.9613202 ]
#  [0.95879054]
#  [0.057422  ]] 0.040060326
# 3500 [[0.01846499]
#  [0.96299773]
#  [0.9605413 ]
#  [0.05502177]] 0.03829837
# 3600 [[0.01762188]
#  [0.96454597]
#  [0.9621612 ]
#  [0.05279923]] 0.03667357
# 3700 [[0.01684618]
#  [0.9659787 ]
#  [0.96366376]
#  [0.050736  ]] 0.0351711
# 3800 [[0.01613047]
#  [0.96730775]
#  [0.9650607 ]
#  [0.04881619]] 0.033778194
# 3900 [[0.01546848]
#  [0.9685439 ]
#  [0.96636236]
#  [0.04702594]] 0.032483704
# 4000 [[0.01485461]
#  [0.969696  ]
#  [0.9675779 ]
#  [0.04535288]] 0.0312779
# 4100 [[0.01428407]
#  [0.97077227]
#  [0.968715  ]
#  [0.04378636]] 0.030152291
# 4200 [[0.01375261]
#  [0.97177935]
#  [0.96978104]
#  [0.04231669]] 0.029099401
# 4300 [[0.01325656]
#  [0.97272384]
#  [0.97078216]
#  [0.04093567]] 0.02811265
# 4400 [[0.01279263]
#  [0.973611  ]
#  [0.9717238 ]
#  [0.0396356 ]] 0.027186194
# 4500 [[0.01235796]
#  [0.9744459 ]
#  [0.9726112 ]
#  [0.03840979]] 0.026314748
# 4600 [[0.01194997]
#  [0.9752329 ]
#  [0.9734484 ]
#  [0.03725227]] 0.0254938
# 4700 [[0.01156637]
#  [0.97597575]
#  [0.9742397 ]
#  [0.03615766]] 0.024719201
# 4800 [[0.01120513]
#  [0.97667795]
#  [0.9749885 ]
#  [0.03512109]] 0.023987234
# 4900 [[0.01086444]
#  [0.97734284]
#  [0.97569805]
#  [0.03413819]] 0.023294572
# 5000 [[0.01054265]
#  [0.97797304]
#  [0.9763713 ]
#  [0.033205  ]] 0.022638239
# 5100 [[0.01023829]
#  [0.97857124]
#  [0.9770108 ]
#  [0.03231797]] 0.022015523
# 5200 [[0.00995004]
#  [0.9791397 ]
#  [0.97761905]
#  [0.03147381]] 0.02142395
# 5300 [[0.0096767 ]
#  [0.9796806 ]
#  [0.9781982 ]
#  [0.03066964]] 0.02086132
# 5400 [[0.0094172 ]
#  [0.9801957 ]
#  [0.9787502 ]
#  [0.02990268]] 0.02032563
# 5500 [[0.00917054]
#  [0.98068696]
#  [0.97927684]
#  [0.02917053]] 0.019815037
# 5600 [[0.00893581]
#  [0.98115575]
#  [0.9797798 ]
#  [0.02847089]] 0.019327877
# 5700 [[0.0087122 ]
#  [0.9816036 ]
#  [0.98026067]
#  [0.02780169]] 0.018862568
# 5800 [[0.00849898]
#  [0.98203206]
#  [0.9807207 ]
#  [0.02716107]] 0.01841773
# 5900 [[0.00829547]
#  [0.9824421 ]
#  [0.9811613 ]
#  [0.02654727]] 0.017992092
# 6000 [[0.00810103]
#  [0.9828348 ]
#  [0.98158354]
#  [0.02595869]] 0.0175845
# 6100 [[0.00791509]
#  [0.9832114 ]
#  [0.9819886 ]
#  [0.02539385]] 0.017193776
# 6200 [[0.00773713]
#  [0.9835728 ]
#  [0.9823773 ]
#  [0.02485135]] 0.016819015
# 6300 [[0.00756665]
#  [0.9839198 ]
#  [0.98275083]
#  [0.0243299 ]] 0.016459182
# 6400 [[0.00740321]
#  [0.98425335]
#  [0.98310995]
#  [0.0238284 ]] 0.016113468
# 6500 [[0.0072464 ]
#  [0.984574  ]
#  [0.9834553 ]
#  [0.02334568]] 0.01578113
# 6600 [[0.00709581]
#  [0.98488265]
#  [0.9837879 ]
#  [0.02288076]] 0.015461352
# 6700 [[0.00695115]
#  [0.9851799 ]
#  [0.98410827]
#  [0.02243274]] 0.015153496
# 6800 [[0.00681202]
#  [0.98546636]
#  [0.984417  ]
#  [0.02200068]] 0.014856898
# 6900 [[0.00667816]
#  [0.98574257]
#  [0.9847149 ]
#  [0.02158376]] 0.014570944
# 7000 [[0.00654927]
#  [0.9860092 ]
#  [0.98500234]
#  [0.02118127]] 0.014295136
# 7100 [[0.0064251 ]
#  [0.9862664 ]
#  [0.9852799 ]
#  [0.02079248]] 0.0140289515
# 7200 [[0.00630538]
#  [0.986515  ]
#  [0.98554796]
#  [0.02041665]] 0.013771898
# 7300 [[0.00618989]
#  [0.9867551 ]
#  [0.9858072 ]
#  [0.02005321]] 0.013523512
# 7400 [[0.00607841]
#  [0.98698735]
#  [0.98605794]
#  [0.01970156]] 0.013283348
# 7500 [[0.00597076]
#  [0.9872121 ]
#  [0.98630047]
#  [0.01936118]] 0.013051084
# 7600 [[0.00586674]
#  [0.9874297 ]
#  [0.9865354 ]
#  [0.01903152]] 0.012826274
# 7700 [[0.00576618]
#  [0.9876403 ]
#  [0.9867628 ]
#  [0.01871212]] 0.012608624
# 7800 [[0.0056689 ]
#  [0.9878444 ]
#  [0.9869833 ]
#  [0.01840245]] 0.012397783
# 7900 [[0.00557475]
#  [0.98804235]
#  [0.98719704]
#  [0.01810214]] 0.012193413
# 8000 [[0.00548359]
#  [0.98823416]
#  [0.98740435]
#  [0.01781075]] 0.011995299
# 8100 [[0.00539529]
#  [0.98842037]
#  [0.98760545]
#  [0.01752797]] 0.0118031185
# 8200 [[0.00530971]
#  [0.98860115]
#  [0.9878007 ]
#  [0.0172533 ]] 0.01161658
# 8300 [[0.00522672]
#  [0.9887765 ]
#  [0.9879902 ]
#  [0.01698652]] 0.011435592
# 8400 [[0.00514626]
#  [0.9889471 ]
#  [0.98817444]
#  [0.01672732]] 0.01125971
# 8500 [[0.00506813]
#  [0.9891127 ]
#  [0.98835343]
#  [0.01647525]] 0.011088861
# 8600 [[0.00499232]
#  [0.9892737 ]
#  [0.98852754]
#  [0.01623022]] 0.010922795
# 8700 [[0.00491867]
#  [0.9894303 ]
#  [0.9886967 ]
#  [0.01599177]] 0.010761362
# 8800 [[0.00484713]
#  [0.9895828 ]
#  [0.9888614 ]
#  [0.01575967]] 0.010604256
# 8900 [[0.00477757]
#  [0.9897311 ]
#  [0.9890216 ]
#  [0.01553379]] 0.01045146
# 9000 [[0.00470995]
#  [0.98987526]
#  [0.98917764]
#  [0.01531376]] 0.010302747
# 9100 [[0.00464419]
#  [0.9900159 ]
#  [0.9893295 ]
#  [0.01509947]] 0.010157932
# 9200 [[0.0045802 ]
#  [0.9901529 ]
#  [0.9894776 ]
#  [0.01489063]] 0.010016849
# 9300 [[0.00451792]
#  [0.9902864 ]
#  [0.9896219 ]
#  [0.01468715]] 0.009879405
# 9400 [[0.00445728]
#  [0.9904165 ]
#  [0.9897625 ]
#  [0.01448866]] 0.009745463
# 9500 [[0.0043982 ]
#  [0.9905434 ]
#  [0.9898996 ]
#  [0.01429503]] 0.00961487
# 9600 [[0.00434066]
#  [0.99066705]
#  [0.9900332 ]
#  [0.01410622]] 0.00948758
# 9700 [[0.00428457]
#  [0.9907879 ]
#  [0.99016374]
#  [0.01392189]] 0.009363306
# 9800 [[0.00422988]
#  [0.99090564]
#  [0.99029106]
#  [0.01374196]] 0.009242121
# 9900 [[0.00417655]
#  [0.99102074]
#  [0.99041533]
#  [0.0135663 ]] 0.009123798
# 10000 [[0.00412454]
#  [0.99113303]
#  [0.99053675]
#  [0.01339474]] 0.009008276
# C_val: 0.009007177
# , Expected: [[0.]
#  [1.]
#  [1.]
#  [0.]] ,
#  Accuracy: 1.0
