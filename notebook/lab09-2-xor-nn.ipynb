# %%
import tensorflow as tf
import numpy as np

# %%
tf.set_random_seed(777)  # for reproducibility

# %%
x_data = [[0,0],
          [0,1],
          [1,0],
          [1,1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# Variables2
W1 = tf.Variable(tf.random_normal([2,2]), name='weight1')
b1 = tf.Variable(tf.random_normal([2]), name='bias1')

# %%
# Layer1
layer = tf.sigmoid(tf.matmul(X, W1)+b1)

# %%
# Variables2
W2 = tf.Variable(tf.random_normal([2,1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')

# %%
# Hypothesis
hypothesis = tf.sigmoid(tf.matmul(layer, W2)+b2)

# %%
# Cost
cost = -tf.reduce_mean(Y*tf.log(hypothesis) + (1-Y)*tf.log(1-hypothesis))

# %%
# Minimize cost
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
# Accuracy
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
# Fit the train
with tf.Session() as session:
    session.run(tf.global_variables_initializer())
    
    for step in range(1, 10001):
        cost_val, hypothesis_val, _ = session.run([cost, hypothesis, train], 
                                                  feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, hypothesis_val, cost_val)
    
    c_val, p_val, a_val = session.run([cost, predicted, accuracy],
                                      feed_dict={X: x_data, Y: y_data})
    print("C_val:", c_val, "\n, Expected:", p_val, ",\n Accuracy:", a_val)
# Out:
# 100 [[0.44664958]
#  [0.4102775 ]
#  [0.4646203 ]
#  [0.4289013 ]] 0.70235336
# 200 [[0.46713814]
#  [0.43325412]
#  [0.48588866]
#  [0.45300144]] 0.69775224
# 300 [[0.48026323]
#  [0.44821733]
#  [0.49941906]
#  [0.4685714 ]] 0.6958515
# 400 [[0.48861063]
#  [0.45791674]
#  [0.5079518 ]
#  [0.47856712]] 0.6950588
# 500 [[0.4938932 ]
#  [0.46421328]
#  [0.5132894 ]
#  [0.48497346]] 0.69471776
# 600 [[0.49721998]
#  [0.4683259 ]
#  [0.5165932 ]
#  [0.4890833 ]] 0.6945604
# 700 [[0.49930194]
#  [0.4710416 ]
#  [0.5186053 ]
#  [0.4917281 ]] 0.6944779
# 800 [[0.50059247]
#  [0.47286457]
#  [0.5197981 ]
#  [0.49343953]] 0.69442636
# 900 [[0.5013807 ]
#  [0.47411722]
#  [0.5204721 ]
#  [0.4945564 ]] 0.69438773
# 1000 [[0.5018503 ]
#  [0.47500494]
#  [0.52081835]
#  [0.49529457]] 0.6943548
# 1100 [[0.50211823]
#  [0.47565848]
#  [0.5209581 ]
#  [0.49579117]] 0.69432455
# 1200 [[0.50225866]
#  [0.47616115]
#  [0.5209684 ]
#  [0.49613354]] 0.69429594
# 1300 [[0.502319 ]
#  [0.476566 ]
#  [0.5208981]
#  [0.4963772]] 0.6942684
# 1400 [[0.502329 ]
#  [0.4769069]
#  [0.5207785]
#  [0.4965575]] 0.6942416
# 1500 [[0.50230783]
#  [0.47720522]
#  [0.52062905]
#  [0.49669692]] 0.69421566
# 1600 [[0.5022675 ]
#  [0.47747472]
#  [0.5204623 ]
#  [0.49680963]] 0.69419026
# 1700 [[0.50221574]
#  [0.47772422]
#  [0.52028614]
#  [0.49690482]] 0.6941656
# 1800 [[0.50215733]
#  [0.47795928]
#  [0.52010566]
#  [0.49698824]] 0.6941415
# 1900 [[0.50209546]
#  [0.47818345]
#  [0.5199238 ]
#  [0.49706358]] 0.6941181
# 2000 [[0.502032  ]
#  [0.47839913]
#  [0.5197427 ]
#  [0.49713323]] 0.69409513
# 2100 [[0.5019681 ]
#  [0.47860786]
#  [0.51956356]
#  [0.49719864]] 0.6940727
# 2200 [[0.5019046 ]
#  [0.47881052]
#  [0.519387  ]
#  [0.49726087]] 0.69405097
# 2300 [[0.5018419 ]
#  [0.4790078 ]
#  [0.51921356]
#  [0.4973204 ]] 0.6940296
# 2400 [[0.50178045]
#  [0.47920027]
#  [0.51904345]
#  [0.49737787]] 0.6940088
# 2500 [[0.50172025]
#  [0.47938815]
#  [0.5188769 ]
#  [0.49743336]] 0.69398844
# 2600 [[0.5016615 ]
#  [0.4795717 ]
#  [0.5187139 ]
#  [0.49748713]] 0.6939686
# 2700 [[0.50160414]
#  [0.47975102]
#  [0.5185544 ]
#  [0.49753916]] 0.6939491
# 2800 [[0.50154823]
#  [0.47992638]
#  [0.51839846]
#  [0.49758983]] 0.69393015
# 2900 [[0.5014939 ]
#  [0.48009777]
#  [0.5182461 ]
#  [0.49763894]] 0.6939115
# 3000 [[0.50144094]
#  [0.48026544]
#  [0.51809716]
#  [0.4976867 ]] 0.6938934
# 3100 [[0.5013895 ]
#  [0.48042935]
#  [0.51795167]
#  [0.49773312]] 0.69387555
# 3200 [[0.50133944]
#  [0.48058978]
#  [0.51780957]
#  [0.49777827]] 0.6938581
# 3300 [[0.5012908 ]
#  [0.48074654]
#  [0.51767075]
#  [0.49782217]] 0.693841
# 3400 [[0.5012435 ]
#  [0.4808999 ]
#  [0.51753515]
#  [0.4978647 ]] 0.69382423
# 3500 [[0.5011975 ]
#  [0.4810498 ]
#  [0.51740277]
#  [0.49790606]] 0.69380784
# 3600 [[0.5011529 ]
#  [0.48119637]
#  [0.5172735 ]
#  [0.49794626]] 0.69379175
# 3700 [[0.5011096 ]
#  [0.48133978]
#  [0.51714736]
#  [0.4979853 ]] 0.693776
# 3800 [[0.5010675 ]
#  [0.48147997]
#  [0.5170242 ]
#  [0.49802324]] 0.6937605
# 3900 [[0.5010267 ]
#  [0.48161703]
#  [0.516904  ]
#  [0.49806005]] 0.6937454
# 4000 [[0.50098705]
#  [0.48175102]
#  [0.51678675]
#  [0.49809563]] 0.6937304
# 4100 [[0.5009486 ]
#  [0.48188198]
#  [0.5166724 ]
#  [0.4981303 ]] 0.6937158
# 4200 [[0.50091136]
#  [0.48201   ]
#  [0.5165608 ]
#  [0.49816385]] 0.69370145
# 4300 [[0.50087523]
#  [0.48213518]
#  [0.51645195]
#  [0.49819645]] 0.69368744
# 4400 [[0.50084025]
#  [0.48225746]
#  [0.5163459 ]
#  [0.49822798]] 0.6936735
# 4500 [[0.50080633]
#  [0.48237696]
#  [0.51624244]
#  [0.4982586 ]] 0.6936599
# 4600 [[0.5007735 ]
#  [0.4824938 ]
#  [0.51614165]
#  [0.49828818]] 0.6936465
# 4700 [[0.50074166]
#  [0.48260787]
#  [0.5160434 ]
#  [0.49831685]] 0.6936333
# 4800 [[0.50071096]
#  [0.48271936]
#  [0.5159477 ]
#  [0.49834457]] 0.69362044
# 4900 [[0.5006812 ]
#  [0.48282826]
#  [0.5158545 ]
#  [0.49837145]] 0.6936077
# 5000 [[0.50065243]
#  [0.48293456]
#  [0.51576376]
#  [0.49839738]] 0.6935951
# 5100 [[0.50062466]
#  [0.48303846]
#  [0.5156754 ]
#  [0.4984225 ]] 0.6935828
# 5200 [[0.5005978 ]
#  [0.48313993]
#  [0.5155895 ]
#  [0.49844676]] 0.6935706
# 5300 [[0.50057185]
#  [0.4832389 ]
#  [0.51550585]
#  [0.49847013]] 0.6935586
# 5400 [[0.5005468 ]
#  [0.48333558]
#  [0.5154245 ]
#  [0.49849275]] 0.6935468
# 5500 [[0.5005227 ]
#  [0.48342994]
#  [0.5153454 ]
#  [0.49851456]] 0.69353515
# 5600 [[0.5004994 ]
#  [0.48352203]
#  [0.5152685 ]
#  [0.4985355 ]] 0.69352365
# 5700 [[0.5004771 ]
#  [0.48361188]
#  [0.5151939 ]
#  [0.49855578]] 0.6935123
# 5800 [[0.5004555 ]
#  [0.4836995 ]
#  [0.51512134]
#  [0.49857524]] 0.6935011
# 5900 [[0.50043476]
#  [0.48378497]
#  [0.5150509 ]
#  [0.49859396]] 0.6934901
# 6000 [[0.50041485]
#  [0.4838683 ]
#  [0.5149826 ]
#  [0.498612  ]] 0.69347924
# 6100 [[0.50039566]
#  [0.4839496 ]
#  [0.5149163 ]
#  [0.49862927]] 0.6934684
# 6200 [[0.5003773 ]
#  [0.4840289 ]
#  [0.5148521 ]
#  [0.49864593]] 0.6934577
# 6300 [[0.50035965]
#  [0.4841061 ]
#  [0.5147898 ]
#  [0.49866188]] 0.69344723
# 6400 [[0.5003427]
#  [0.4841813]
#  [0.5147295]
#  [0.4986772]] 0.69343686
# 6500 [[0.5003266 ]
#  [0.48425466]
#  [0.51467115]
#  [0.4986919 ]] 0.6934266
# 6600 [[0.50031114]
#  [0.48432606]
#  [0.51461464]
#  [0.4987059 ]] 0.6934165
# 6700 [[0.5002963 ]
#  [0.4843956 ]
#  [0.51456004]
#  [0.49871927]] 0.69340634
# 6800 [[0.5002822 ]
#  [0.48446324]
#  [0.51450723]
#  [0.4987321 ]] 0.69339645
# 6900 [[0.50026876]
#  [0.4845291 ]
#  [0.5144563 ]
#  [0.4987443 ]] 0.69338655
# 7000 [[0.500256  ]
#  [0.48459315]
#  [0.51440716]
#  [0.49875593]] 0.6933768
# 7100 [[0.5002438]
#  [0.4846554]
#  [0.5143597]
#  [0.4987669]] 0.6933671
# 7200 [[0.5002323 ]
#  [0.4847159 ]
#  [0.51431406]
#  [0.49877736]] 0.6933576
# 7300 [[0.5002214 ]
#  [0.48477474]
#  [0.5142701 ]
#  [0.4987873 ]] 0.69334805
# 7400 [[0.500211  ]
#  [0.4848319 ]
#  [0.51422787]
#  [0.49879667]] 0.69333863
# 7500 [[0.5002012 ]
#  [0.4848874 ]
#  [0.5141873 ]
#  [0.49880552]] 0.6933293
# 7600 [[0.50019205]
#  [0.4849413 ]
#  [0.51414835]
#  [0.49881396]] 0.69332004
# 7700 [[0.5001834 ]
#  [0.48499358]
#  [0.51411104]
#  [0.49882177]] 0.69331074
# 7800 [[0.50017536]
#  [0.48504427]
#  [0.51407534]
#  [0.49882913]] 0.6933017
# 7900 [[0.5001677]
#  [0.4850934]
#  [0.5140412]
#  [0.498836 ]] 0.6932926
# 8000 [[0.50016075]
#  [0.485141  ]
#  [0.5140086 ]
#  [0.49884236]] 0.69328356
# 8100 [[0.5001542 ]
#  [0.48518714]
#  [0.5139775 ]
#  [0.4988483 ]] 0.6932746
# 8200 [[0.5001482 ]
#  [0.4852317 ]
#  [0.513948  ]
#  [0.49885374]] 0.6932657
# 8300 [[0.5001427 ]
#  [0.48527488]
#  [0.51392007]
#  [0.4988588 ]] 0.69325686
# 8400 [[0.50013757]
#  [0.4853166 ]
#  [0.5138935 ]
#  [0.49886343]] 0.69324803
# 8500 [[0.500133  ]
#  [0.48535687]
#  [0.5138684 ]
#  [0.49886757]] 0.6932392
# 8600 [[0.5001288 ]
#  [0.48539573]
#  [0.5138448 ]
#  [0.4988714 ]] 0.6932305
# 8700 [[0.5001251 ]
#  [0.4854332 ]
#  [0.5138226 ]
#  [0.49887475]] 0.69322187
# 8800 [[0.50012183]
#  [0.48546934]
#  [0.5138018 ]
#  [0.49887767]] 0.69321316
# 8900 [[0.500119  ]
#  [0.48550412]
#  [0.5137824 ]
#  [0.49888027]] 0.6932046
# 9000 [[0.5001165]
#  [0.4855375]
#  [0.5137644]
#  [0.4988824]] 0.693196
# 9100 [[0.50011456]
#  [0.48556972]
#  [0.51374775]
#  [0.49888432]] 0.6931875
# 9200 [[0.50011283]
#  [0.4856005 ]
#  [0.51373243]
#  [0.49888575]] 0.69317895
# 9300 [[0.50011164]
#  [0.48563015]
#  [0.5137185 ]
#  [0.49888685]] 0.69317037
# 9400 [[0.50011075]
#  [0.48565847]
#  [0.5137058 ]
#  [0.49888763]] 0.69316196
# 9500 [[0.5001102 ]
#  [0.48568547]
#  [0.5136944 ]
#  [0.498888  ]] 0.6931535
# 9600 [[0.5001101 ]
#  [0.48571134]
#  [0.5136844 ]
#  [0.4988881 ]] 0.69314504
# 9700 [[0.5001102 ]
#  [0.48573592]
#  [0.5136756 ]
#  [0.4988878 ]] 0.6931366
# 9800 [[0.5001108 ]
#  [0.48575938]
#  [0.51366806]
#  [0.49888727]] 0.6931282
# 9900 [[0.50011164]
#  [0.48578167]
#  [0.5136618 ]
#  [0.49888644]] 0.6931198
# 10000 [[0.5001128 ]
#  [0.4858027 ]
#  [0.51365674]
#  [0.49888527]] 0.6931114
# C_val: 0.69311136
# , Expected: [[1.]
#  [0.]
#  [1.]
#  [0.]] ,
#  Accuracy: 0.5
